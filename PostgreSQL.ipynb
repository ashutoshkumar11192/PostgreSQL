# %%
#import library for PostgreSQL

import psycopg2

# %%
#connect database succesfully

conn = psycopg2.connect(database="dvdrental", user = "postgres", password = "password", host = "127.0.0.1", port = "5432")

# %%
cur = conn.cursor()

# %%
#fetch data successfully from database

cur.execute('select * from customer')

# %%
data = cur.fetchmany(100)

# %%
data
# Out:
# [(524,
#   1,
#   'Jared',
#   'Ely',
#   'jared.ely@sakilacustomer.org',
#   530,
#   True,
#   datetime.date(2006, 2, 14),
#   datetime.datetime(2013, 5, 26, 14, 49, 45, 738000),
#   1),
#  (1,
#   1,
#   'Mary',
#   'Smith',
#   'mary.smith@sakilacustomer.org',
#   5,
#   True,
#   datetime.date(2006, 2, 14),
#   datetime.datetime(2013, 5, 26, 14, 49, 45, 738000),
#   1),
#  (2,
#   1,
#   'Patricia',
#   'Johnson',
#   'patricia.johnson@sakilacustomer.org',
#   6,
#   True,
#   datetime.date(2006, 2, 14),
#   datetime.datetime(2013, 5, 26, 14, 49, 45, 738000),
#   1),
#  (3,
#   1,
#   'Linda',
#   'Williams',
#   'linda.williams@sakilacustomer.org',
#   7,
#   True,
#   datetime.date(2006, 2, 14),
#   datetime.datetime(2013, 5, 26, 14, 49, 45, 738000),
#   1),
#  (4,
#   2,
#   'Barbara',
#   'Jones',
#   'barbara.jones@sakilacustomer.org',
#   8,
#   True,
#   datetime.date(2006, 2, 14),
#   datetime.datetime(2013, 5, 26, 14, 49, 45, 738000),
#   1),
#  (5,
#   1,
# ...

# %%
#import pandas library for data manupulation

import pandas

# %%
#load data into dataframe

data = pandas.DataFrame(data)

# %%
#data in dataframe format

data
# Out:
#       0  1         2          3                                    4    5  \
# 0   524  1     Jared        Ely         jared.ely@sakilacustomer.org  530
# 1     1  1      Mary      Smith        mary.smith@sakilacustomer.org    5
# 2     2  1  Patricia    Johnson  patricia.johnson@sakilacustomer.org    6
# 3     3  1     Linda   Williams    linda.williams@sakilacustomer.org    7
# 4     4  2   Barbara      Jones     barbara.jones@sakilacustomer.org    8
# ..  ... ..       ...        ...                                  ...  ...
# 95   95  2     Paula     Bryant      paula.bryant@sakilacustomer.org   99
# 96   96  1     Diana  Alexander   diana.alexander@sakilacustomer.org  100
# 97   97  2     Annie    Russell     annie.russell@sakilacustomer.org  101
# 98   98  1   Lillian    Griffin   lillian.griffin@sakilacustomer.org  102
# 99   99  2     Emily       Diaz        emily.diaz@sakilacustomer.org  103
#
#        6           7                       8  9
# ...
